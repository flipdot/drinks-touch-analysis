# %%
# %matplotlib inline
import pandas as pd
import pylab as plt

# %%
df = pd.read_csv("drinks.csv", sep="\t")
df = df.iloc[:-1]
df['timestamp'] = pd.to_datetime(df['timestamp'])
len(df)
df.head()
# Out:
#                    timestamp                  name  type
# 0 2019-04-09 19:35:06.827732          Mio Mio Cola  cola
# 1 2019-04-09 19:35:01.869332        MIO MIO Ginger  mate
# 2 2019-04-09 18:33:12.085979          Mio Mio Cola  cola
# 3 2019-04-09 18:21:23.380076  Fortuna Apfelschorle  saft
# 4 2019-04-09 18:14:22.028130          Mio Mio Cola  cola

# %%
df[['timestamp','name']].groupby('name').count().plot.bar()

# %%
df['month'] = df['timestamp'].dt.to_period('M')
df[['month', 'name']].groupby(['month', 'name']).size().plot()
#TODO
